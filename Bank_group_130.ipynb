# %% [markdown]
# # Direct Marketing campaing

# %% [markdown]
# The data is related with direct marketing campaigns (phone calls) of a Portuguese banking institution. The classification goal is to predict if the client will subscribe a term deposit (variable y).

# %% [markdown]
# ## Fetching Data

# %% [markdown]
# ### Function to fetch data

# %%
import os
import zipfile
from six.moves import urllib

#DOWNLOAD_ROOT = "https://archive.ics.uci.edu/ml/"
#BANK_PATH = "machine-learning-databases/00222"
BANK_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank.zip"

LOCAL_DIR = "Bank_Data/"

def fetching_bank_data(url = BANK_URL, local_dir = LOCAL_DIR):
    if not os.path.isdir(local_dir):
        os.makedirs(local_dir)
    zip_path = os.path.join(local_dir, "bank.zip")
    urllib.request.urlretrive(url,zip_path)
    Bank_zip = zipfile.open(url)
    Bank_zip.extractall(path = zip_path)
    Bank_zip.close()

# %%
import pandas as pd
import numpy as np
df =pd.read_csv("C:/Ganesh/Data_Science/MTech/Semester_2/Semester #2/ML/Assignment_2/bank.csv")

# %%
### Quick Look at Data structure

# %%
df.head()
# Out:
#   age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0  30;"unemployed";"married";"primary";"no";1787;...
# 1  33;"services";"married";"secondary";"no";4789;...
# 2  35;"management";"single";"tertiary";"no";1350;...
# 3  30;"management";"married";"tertiary";"no";1476...
# 4  59;"blue-collar";"married";"secondary";"no";0;...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 1 columns):
# age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"    4521 non-null object
# dtypes: object(1)
# memory usage: 35.4+ KB

# %% [markdown]
# ### df1 is pandas series inorder to consider split option

# %%
df1 = df.iloc[:,0]

# %%
df1.str.split(pat = ';', expand = True)
# Out:
#       0                1           2            3      4      5      6   \
# 0     30     "unemployed"   "married"    "primary"   "no"   1787   "no"
# 1     33       "services"   "married"  "secondary"   "no"   4789  "yes"
# 2     35     "management"    "single"   "tertiary"   "no"   1350  "yes"
# 3     30     "management"   "married"   "tertiary"   "no"   1476  "yes"
# 4     59    "blue-collar"   "married"  "secondary"   "no"      0  "yes"
# 5     35     "management"    "single"   "tertiary"   "no"    747   "no"
# 6     36  "self-employed"   "married"   "tertiary"   "no"    307  "yes"
# 7     39     "technician"   "married"  "secondary"   "no"    147  "yes"
# 8     41   "entrepreneur"   "married"   "tertiary"   "no"    221  "yes"
# 9     43       "services"   "married"    "primary"   "no"    -88  "yes"
# 10    39       "services"   "married"  "secondary"   "no"   9374  "yes"
# 11    43         "admin."   "married"  "secondary"   "no"    264  "yes"
# ...

# %% [markdown]
# # More simple approach for loading

# %%
pdf = pd.read_csv("C:/Ganesh/Data_Science/MTech/Semester_2/Semester #2/ML/Assignment_2/bank.csv",sep = ';').replace('"','',regex= True)

# %%
pdf.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
pdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 17 columns):
# age          4521 non-null int64
# job          4521 non-null object
# marital      4521 non-null object
# education    4521 non-null object
# default      4521 non-null object
# balance      4521 non-null int64
# housing      4521 non-null object
# loan         4521 non-null object
# contact      4521 non-null object
# day          4521 non-null int64
# month        4521 non-null object
# duration     4521 non-null int64
# campaign     4521 non-null int64
# pdays        4521 non-null int64
# previous     4521 non-null int64
# poutcome     4521 non-null object
# y            4521 non-null object
# dtypes: int64(7), object(10)
# memory usage: 600.5+ KB

# %%
pdf['poutcome'].value_counts()
# Out:
# unknown    3705
# failure     490
# other       197
# success     129
# Name: poutcome, dtype: int64

# %%
pdf.select_dtypes(exclude = np.number).head()
# Out:
#            job  marital  education default housing loan   contact month  \
# 0   unemployed  married    primary      no      no   no  cellular   oct
# 1     services  married  secondary      no     yes  yes  cellular   may
# 2   management   single   tertiary      no     yes   no  cellular   apr
# 3   management  married   tertiary      no     yes  yes   unknown   jun
# 4  blue-collar  married  secondary      no     yes   no   unknown   may
#
#   poutcome   y
# 0  unknown  no
# 1  failure  no
# 2  failure  no
# 3  unknown  no
# 4  unknown  no

# %%
pdf['poutcome'].value_counts() # drop - more unknown
# Out:
# unknown    3705
# failure     490
# other       197
# success     129
# Name: poutcome, dtype: int64

# %%
pdf['month'].value_counts() # one hot encoding
# Out:
# may    1398
# jul     706
# aug     633
# jun     531
# nov     389
# apr     293
# feb     222
# jan     148
# oct      80
# sep      52
# mar      49
# dec      20
# Name: month, dtype: int64

# %%
pdf['contact'].value_counts() #drop - more unknown
# Out:
# cellular     2896
# unknown      1324
# telephone     301
# Name: contact, dtype: int64

# %%
pdf['loan'].value_counts() # one hot
# Out:
# no     3830
# yes     691
# Name: loan, dtype: int64

# %%
pdf['housing'].value_counts() # one hot
# Out:
# yes    2559
# no     1962
# Name: housing, dtype: int64

# %%
pdf['default'].value_counts() # one hot
# Out:
# no     4445
# yes      76
# Name: default, dtype: int64

# %%
pdf['education'].value_counts() # Replace with mode & dummies
# Out:
# secondary    2306
# tertiary     1350
# primary       678
# unknown       187
# Name: education, dtype: int64

# %%
pdf['marital'].value_counts() # one hot
# Out:
# married     2797
# single      1196
# divorced     528
# Name: marital, dtype: int64

# %%
pdf['job'].value_counts() # dummies
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
pdf.drop(['poutcome'], axis = 1).head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous   y
# 0  cellular   19   oct        79         1     -1         0  no
# 1  cellular   11   may       220         1    339         4  no
# 2  cellular   16   apr       185         1    330         1  no
# 3   unknown    3   jun       199         4     -1         0  no
# 4   unknown    5   may       226         1     -1         0  no

# %%
pdf.drop(['contact'], axis = 1).head()
# Out:
#    age          job  marital  education default  balance housing loan  day  \
# 0   30   unemployed  married    primary      no     1787      no   no   19
# 1   33     services  married  secondary      no     4789     yes  yes   11
# 2   35   management   single   tertiary      no     1350     yes   no   16
# 3   30   management  married   tertiary      no     1476     yes  yes    3
# 4   59  blue-collar  married  secondary      no        0     yes   no    5
#
#   month  duration  campaign  pdays  previous poutcome   y
# 0   oct        79         1     -1         0  unknown  no
# 1   may       220         1    339         4  failure  no
# 2   apr       185         1    330         1  failure  no
# 3   jun       199         4     -1         0  unknown  no
# 4   may       226         1     -1         0  unknown  no

# %%
pdf['education']=pdf['education'].str.replace('unknown','secondary')

# %%
pdf['education'].value_counts()
# Out:
# secondary    2493
# tertiary     1350
# primary       678
# Name: education, dtype: int64

# %%
pdf.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
pdf['job'].value_counts()
# Out:
# management       969
# blue-collar      946
# technician       768
# admin.           478
# services         417
# retired          230
# self-employed    183
# entrepreneur     168
# unemployed       128
# housemaid        112
# student           84
# unknown           38
# Name: job, dtype: int64

# %%
pdf['job']=pdf['job'].str.replace('unknown','management')

# %%
pdf['job'].value_counts()
# Out:
# management       1007
# blue-collar       946
# technician        768
# admin.            478
# services          417
# retired           230
# self-employed     183
# entrepreneur      168
# unemployed        128
# housemaid         112
# student            84
# Name: job, dtype: int64

# %%
pdf['age'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 4491    False
# 4492    False
# 4493    False
# 4494    False
# 4495    False
# 4496    False
# 4497    False
# 4498    False
# 4499    False
# 4500    False
# 4501    False
# 4502    False
# 4503    False
# 4504    False
# 4505    False
# 4506    False
# 4507    False
# 4508    False
# 4509    False
# 4510    False
# 4511    False
# 4512    False
# 4513    False
# 4514    False
# 4515    False
# 4516    False
# 4517    False
# 4518    False
# 4519    False
# 4520    False
# ...

# %%
pdf.drop(['month'], axis = 1).head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19        79         1     -1         0  unknown  no
# 1  cellular   11       220         1    339         4  failure  no
# 2  cellular   16       185         1    330         1  failure  no
# 3   unknown    3       199         4     -1         0  unknown  no
# 4   unknown    5       226         1     -1         0  unknown  no

# %%
import pickle
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn import model_selection
from sklearn import metrics
import pandas as pd
#import pylab as plb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
le = preprocessing.LabelEncoder()

# %%
pdf.job = le.fit_transform(pdf.job)

# %%
pdf.marital = le.fit_transform(pdf.marital)

# %%
pdf.education = le.fit_transform(pdf.education)
pdf.housing = le.fit_transform(pdf.housing)
pdf.loan = le.fit_transform(pdf.loan)
pdf.poutcome = le.fit_transform(pdf.poutcome)
pdf.y = le.fit_transform(pdf.y)
pdf.head()
pdf.shape
X = pdf.iloc[:,0:12]
X[0:10]
y = pdf.iloc[:,13]
y[0:10]
x_train, x_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=0) #80/20 split

x_train.shape, y_train.shape

x_test.shape, y_test.shape




#####Training the model###


from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim=12, activation='tanh'))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
x_train_keras = np.array(x_train)
y_train_keras = np.array(y_train)
#print(x_train_keras.shape)
y_train_keras = y_train_keras.reshape(y_train_keras.shape[0], 1)
model.fit(np.array(x_train_keras), np.array(y_train_keras), epochs=10, batch_size=128, shuffle=True)

scores = model.evaluate(np.array(x_test), np.array(y_test))
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-221-802434cf07ea> in <module>()
#      22
#      23
# ---> 24 from keras.models import Sequential
#      25 from keras.layers import Dense
#      26
#
# ModuleNotFoundError: No module named 'keras'
